# %%
import numpy as np
import pandas as pd 
import json
import matplotlib.pyplot as plt

# %%
with open('./packages-used-in-kernels/py_packages.json') as f:
    data = json.load(f)

# %%
len(data)
# Out:
# 4459

# %%
data = pd.read_json('./packages-used-in-kernels/py_packages.json')

# %%
def onlypackage(package):
    try:
        return package[1]
    except:
        return np.nan
for i in data.columns:
    data[i] = list(map(onlypackage,data[i]))

# %%
data.head()
# Out:
#          0       1          2                  3        4    5    6    7   \
# 0  datetime   sleep        NaN                NaN      NaN  NaN  NaN  NaN
# 1      this     NaN        NaN                NaN      NaN  NaN  NaN  NaN
# 2   sqlite3  pandas  haversine                NaN      NaN  NaN  NaN  NaN
# 3    pandas  Series      numpy  matplotlib.pyplot  seaborn  NaN  NaN  NaN
# 4       sys     NaN        NaN                NaN      NaN  NaN  NaN  NaN
#
#     8    9    10   11   12   13   14
# 0  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 1  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 2  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 3  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 4  NaN  NaN  NaN  NaN  NaN  NaN  NaN

# %%
dataT= data.T
dataT.head()
# Out:
#        0     1          2                  3    4                  5     \
# 0  datetime  this    sqlite3             pandas  sys             pandas
# 1     sleep   NaN     pandas             Series  NaN             Series
# 2       NaN   NaN  haversine              numpy  NaN              numpy
# 3       NaN   NaN        NaN  matplotlib.pyplot  NaN  matplotlib.pyplot
# 4       NaN   NaN        NaN            seaborn  NaN            seaborn
#
#      6                  7       8     9      ...                 4449  \
# 0  pandas             pandas  pandas  this   ...    matplotlib.pyplot
# 1     NaN             Series     NaN   NaN   ...                numpy
# 2     NaN              numpy     NaN   NaN   ...           tensorflow
# 3     NaN  matplotlib.pyplot     NaN   NaN   ...     LinearRegression
# 4     NaN            seaborn     NaN   NaN   ...                 mean
#
#       4450               4451               4452        4453  \
# ...

# %%
data['number'] = data.agg("count", axis="columns")

# %%
packagebynumber = data.groupby("number")["number"].count()
#갯수별 사용
packagebynumber

# %%
len(packagebynumber.index)
# Out:
# 16

# %%
x = packagebynumber.index
y = packagebynumber.loc[x]
plt.bar(x, y)
# Out:
# <BarContainer object of 16 artists>

# %%
data['number'].mean()
#평균 4.67개를 사용
# Out:
# 4.670329670329671

# %%
data['howmany'] = list(map(lambda x: x[x.isnull() == False].count(),data))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-133-b24ed86403ea> in <module>()
# ----> 1 data['howmany'] = list(map(lambda x: x[x.isnull() == False].count(),data))
#
# <ipython-input-133-b24ed86403ea> in <lambda>(x)
# ----> 1 data['howmany'] = list(map(lambda x: x[x.isnull() == False].count(),data))
#
# AttributeError: 'int' object has no attribute 'isnull'

# %%
datatrans
# Out:
#         0     1          2                  3    4                  5     \
# 0   datetime  this    sqlite3             pandas  sys             pandas
# 1      sleep   NaN     pandas             Series  NaN             Series
# 2        NaN   NaN  haversine              numpy  NaN              numpy
# 3        NaN   NaN        NaN  matplotlib.pyplot  NaN  matplotlib.pyplot
# 4        NaN   NaN        NaN            seaborn  NaN            seaborn
# 5        NaN   NaN        NaN                NaN  NaN                NaN
# 6        NaN   NaN        NaN                NaN  NaN                NaN
# 7        NaN   NaN        NaN                NaN  NaN                NaN
# 8        NaN   NaN        NaN                NaN  NaN                NaN
# 9        NaN   NaN        NaN                NaN  NaN                NaN
# 10       NaN   NaN        NaN                NaN  NaN                NaN
# 11       NaN   NaN        NaN                NaN  NaN                NaN
# ...
